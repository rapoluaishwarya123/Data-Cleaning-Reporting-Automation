# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')
data
# Out:
#   Name   Age   Salary
# 0    A  25.0  20000.0
# 1    B   NaN  25000.0
# 2    C  30.0  30000.0
# 3    A  25.0  20000.0
# 4    D  28.0      NaN
# 5    E  35.0  40000.0
# 6    F   NaN  35000.0

# %%
data.isnull().sum()
# Out:
# Name      0
# Age       2
# Salary    1
# dtype: int64

# %%
data['Age'] = data['Age'].fillna(data['Age'].mean())
data['Salary'] = data['Salary'].fillna(data['Salary'].mean())

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#   Name   Age        Salary
# 0    A  25.0  20000.000000
# 1    B  28.6  25000.000000
# 2    C  30.0  30000.000000
# 4    D  28.0  28333.333333
# 5    E  35.0  40000.000000
# 6    F  28.6  35000.000000

# %%
print("Summary Report")
print(data.describe())
# Out:
# Summary Report
#              Age        Salary
# count   6.000000      6.000000
# mean   29.200000  29722.222222
# std     3.288769   7103.728807
# min    25.000000  20000.000000
# 25%    28.150000  25833.333333
# 50%    28.600000  29166.666667
# 75%    29.650000  33750.000000
# max    35.000000  40000.000000

# %%
print(data.groupby('Name').mean())
# Out:
#        Age        Salary
# Name
# A     25.0  20000.000000
# B     28.6  25000.000000
# C     30.0  30000.000000
# D     28.0  28333.333333
# E     35.0  40000.000000
# F     28.6  35000.000000

# %%
plt.bar(data['Name'], data['Salary'])
plt.xlabel("Name")
plt.ylabel("Salary")
plt.title("Salary Report")
plt.show()

# %%
data.to_csv('cleaned_data.csv', index=False)
